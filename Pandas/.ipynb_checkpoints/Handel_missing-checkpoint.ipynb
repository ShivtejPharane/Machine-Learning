# %%
import pandas as pd

# %%
df = pd.read_csv("sample_missing_values.csv")
df.isnull()
df.isnull().sum()
df.dropna()
df.dropna(axis=1)
df.fillna(100)
age_mean = df["Age"].mean()
cleande_data = df.copy()
cleande_data = cleande_data["Age"].fillna(age_mean)
cleande_data
df.ffill() # forward fill 
df.bfill()
# Out:
#    ID    Name   Age       City
# 0   1   Aarav  21.0       Pune
# 1   2    Diya  20.0     Mumbai
# 2   3   Sneha  20.0      Delhi
# 3   4   Sneha  23.0  Hyderabad
# 4   5   Karan  21.0  Hyderabad
# 5   6   Priya  21.0    Chennai
# 6   7  Ananya  25.0    Kolkata
# 7   8  Ananya  22.0  Ahmedabad
# 8   9   Rahul  20.0  Ahmedabad
# 9  10   Meera  20.0     Nagpur

# %%
##Duplication
df["Age"].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9     True
# Name: Age, dtype: bool

# %%
#data types
df.dtypes
df["Age"] = df["Age"].ffill().astype("int64")
df
#date time
aqi_data =pd.read_csv("globalAirQuality.csv")
aqi_data["timestamp"].dtypes
pd.to_datetime("2005-05-29")

aqi_data["timestamp"] = pd.to_datetime(aqi_data["timestamp"])
aqi_data["timestamp"].dtypes
# Out:
# dtype('<M8[ns]')
