# %%
import pandas as pd

# %%
info={
    "Name" : ["Shiva","Om","Syoug","Tejas"],
    "CGPA" : [7.0,9.0,8.5,8.7]
}
df = pd.DataFrame(info)
print(df)
# Out:
#     Name  CGPA
# 0  Shiva   7.0
# 1     Om   9.0
# 2  Syoug   8.5
# 3  Tejas   8.7

# %%
df
# Out:
#     Name  CGPA
# 0  Shiva   7.0
# 1     Om   9.0
# 2  Syoug   8.5
# 3  Tejas   8.7

# %% [markdown]
# Series

# %%
s = pd.Series([1,2,3,4,5])
print(s)
print(type(s))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#index
print(s[0])
print(s[1])
# Out:
# 1
# 2

# %%
s = pd.Series([11,25,30,41,50],index=["Shiva","Om","Syoug","Tejas","Alice"])
print(s)
print(s["Shiva"])
print(s.iloc[0])
print(s.index)
# Out:
# Shiva    11
# Om       25
# Syoug    30
# Tejas    41
# Alice    50
# dtype: int64
# 11
# 11
# Index(['Shiva', 'Om', 'Syoug', 'Tejas', 'Alice'], dtype='object')
